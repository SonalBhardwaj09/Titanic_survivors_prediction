# %%
import pandas as pd
import numpy as np

# %%
dftest=pd.read_csv('test.csv')

# %%
dftest
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
ndf=dftest.copy()

# %%
ndf
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
ndf.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
# Assuming df is your original DataFrame

# Define the conditions
condition_male = ndf['Sex'] == 'male'
condition_age_less_than_10 = ndf['Age'] < 10 & 40
condition_class_1 = ndf['Pclass'] == 1
condition_embarked_s = ndf['Embarked'] == 'S'

# Create a new column with selected values based on conditions
ndf['Survived'] = np.select(
    [condition_male & condition_age_less_than_10,
     condition_male & ~condition_age_less_than_10 & condition_class_1,
     condition_embarked_s],
    [0, 1, 1],  # Corresponding values for each condition
    default=0  # Default value for other cases
)

# Create a new DataFrame with specified columns
new_df = ndf[['PassengerId', 'Survived']]

# Display the resulting DataFrame
print(new_df)
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         1
# 4            896         1
# ..           ...       ...
# 413         1305         1
# 414         1306         0
# 415         1307         1
# 416         1308         1
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
new_df.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         1
# 4          896         1

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

# Assuming df is your DataFrame
# You can replace it with the actual name of your DataFrame

# Select features and target variable
features = ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked']
target = 'Survived'

# Create a DataFrame with only the selected features and target variable
data = ndf[features + [target]]

# Drop rows with missing values
data = data.dropna()

# Convert categorical variables to numerical using one-hot encoding
data = pd.get_dummies(data, columns=['Sex', 'Embarked'], drop_first=True)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    data.drop(target, axis=1),
    data[target],
    test_size=0.2,
    random_state=42
)

# Create and train the Random Forest classifier
clf = RandomForestClassifier(random_state=42)
clf.fit(X_train, y_train)

# Make predictions on the test set
y_pred = clf.predict(X_test)

# Evaluate the performance of the model
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)

print(f"Accuracy: {accuracy}")
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Accuracy: 0.9850746268656716
# Confusion Matrix:
# [[14  0]
#  [ 1 52]]

# %%
ndf
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# ...

# %%
# Assuming main_data is your original DataFrame
# If you have a CSV file, you can read it into a DataFrame like this:
# main_data = pd.read_csv('your_dataset.csv')

# Creating a new DataFrame with only 'PassengerId' and 'Survived' and removing the index
selected_columns = ['PassengerId', 'Survived']
new_dataframe = ndf[selected_columns].reset_index(drop=True)

# Displaying the new DataFrame
print(new_dataframe)
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         1
# 4            896         1
# ..           ...       ...
# 413         1305         1
# 414         1306         0
# 415         1307         1
# 416         1308         1
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
ndf
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# ...

# %%
new_dataframe
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         1
# 4            896         1
# ..           ...       ...
# 413         1305         1
# 414         1306         0
# 415         1307         1
# 416         1308         1
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
# Save the new_dataframe to a CSV file
new_dataframe.to_csv('new_dataframe.csv', index=False)
